# %%
import random as R
list = []
for i in range (2500,8000):
    if i % 50 == 0  or i % 100 == 0:
       # print(i)
        list.append(i)

print(list)

list_str = str(list)

filewrite=open("teja.txt",'w')
filewrite.write(list_str)
filewrite.close()
# Out:
# [2500, 2550, 2600, 2650, 2700, 2750, 2800, 2850, 2900, 2950, 3000, 3050, 3100, 3150, 3200, 3250, 3300, 3350, 3400, 3450, 3500, 3550, 3600, 3650, 3700, 3750, 3800, 3850, 3900, 3950, 4000, 4050, 4100, 4150, 4200, 4250, 4300, 4350, 4400, 4450, 4500, 4550, 4600, 4650, 4700, 4750, 4800, 4850, 4900, 4950, 5000, 5050, 5100, 5150, 5200, 5250, 5300, 5350, 5400, 5450, 5500, 5550, 5600, 5650, 5700, 5750, 5800, 5850, 5900, 5950, 6000, 6050, 6100, 6150, 6200, 6250, 6300, 6350, 6400, 6450, 6500, 6550, 6600, 6650, 6700, 6750, 6800, 6850, 6900, 6950, 7000, 7050, 7100, 7150, 7200, 7250, 7300, 7350, 7400, 7450, 7500, 7550, 7600, 7650, 7700, 7750, 7800, 7850, 7900, 7950]

# %%
new_list = []

for ele in list:
    x = R.sample(list,3)
    new_list.append(x)

# %%
print(new_list)
# Out:
# [[7200, 3150, 6000], [6850, 7500, 2500], [5900, 4550, 7800], [4000, 2500, 7500], [7600, 6450, 4700], [3200, 6750, 3400], [4500, 4150, 3150], [3800, 4050, 6900], [4700, 6850, 3500], [4700, 6900, 2600], [4250, 5400, 4700], [5800, 7250, 4200], [3700, 6100, 2900], [3150, 4450, 3900], [4800, 3000, 6100], [5900, 3550, 2650], [5400, 5200, 4050], [7900, 6400, 6750], [7550, 6400, 5200], [5100, 5300, 2900], [6050, 7350, 7000], [2800, 4450, 7000], [6050, 6550, 5950], [2750, 7700, 6850], [3450, 6250, 6350], [7750, 6850, 4500], [6200, 3450, 2750], [7950, 4150, 5050], [5100, 5250, 6800], [6600, 5550, 6250], [4900, 3950, 3550], [6100, 5300, 4100], [3250, 6350, 7150], [2500, 6850, 3550], [5750, 6300, 7450], [7650, 7600, 6200], [3150, 5700, 6300], [3400, 5600, 6150], [7250, 3800, 3000], [3750, 6950, 2650], [3050, 2800, 7200], [7550, 4550, 5500], [2900, 4350, 2600], [5500, 3700, 5850], [6200, 7450, 6850], [2700, 3050, 6100], [7850, 4750, 6000], [4950, 5500, 7350], [4200, 6350, 6650], [7250, 5250, 6350
# ...

# %%
val_3 = str(new_list)
filewrite=open("apple.txt",'w')
filewrite.write(val_3)
filewrite.close()

# %%
def Average(lst):
    return sum(lst) / len(lst)

# %%
for ele in new_list:
    average = Average(ele)

    print("{:.2f}".format(average))
# Out:
# 5450.00
# 5616.67
# 6083.33
# 4666.67
# 6250.00
# 4450.00
# 3933.33
# 4916.67
# 5016.67
# 4733.33
# 4783.33
# 5750.00
# 4233.33
# 3833.33
# 4633.33
# 4033.33
# 4883.33
# 7016.67
# 6383.33
# 4433.33
# 6800.00
# 4750.00
# 6183.33
# 5766.67
# 5350.00
# 6366.67
# 4133.33
# 5716.67
# 5716.67
# 6133.33
# 4133.33
# 5166.67
# 5583.33
# 4300.00
# 6500.00
# 7150.00
# 5050.00
# 5050.00
# 4683.33
# 4450.00
# 4350.00
# 5866.67
# 3283.33
# 5016.67
# 6833.33
# 3950.00
# 6200.00
# 5933.33
# 5733.33
# 6283.33
# 2850.00
# 4650.00
# 4816.67
# 5983.33
# 3300.00
# 5766.67
# 5333.33
# 6716.67
# 5300.00
# 5016.67
# 4616.67
# 4583.33
# 6700.00
# 4283.33
# 5316.67
# 5433.33
# 5383.33
# 5833.33
# 5116.67
# 5166.67
# 6350.00
# 6816.67
# 4066.67
# 4000.00
# 4366.67
# 4483.33
# 4166.67
# 4166.67
# 4150.00
# 3800.00
# 4433.33
# 3683.33
# 4250.00
# 4283.33
# 6400.00
# 5666.67
# 6616.67
# 6350.00
# 3716.67
# 4933.33
# 6066.67
# 6200.00
# 4266.67
# 5883.33
# 6600.00
# 4666.67
# 6216.67
# 4216.67
# 5583.33
# 6750.00
# ...
